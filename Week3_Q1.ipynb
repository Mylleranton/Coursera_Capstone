# %% [markdown]
# ## Notebook for Question 1, Week 3 in the course "Applied Data Science Capstone"

# %% [markdown]
# This course, along with 8 others, are part of the IBM Data Science Professional Certificate

# %%
# !conda install -c anaconda beautifulsoup4 -y
# !conda install -c anaconda lxml -y
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - lxml
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     libxslt-1.1.33             |       h7d1a2b0_0         577 KB  anaconda
#     lxml-4.5.0                 |   py36hefd8a0e_0         1.6 MB  anaconda
#     ------------------------------------------------------------
#                                            Total:         2.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   libxslt            anaconda/linux-64::libxslt-1.1.33-h7d1a2b0_0
#   lxml               anaconda/linux-64::lxml-4.5.0-py36hefd8a0e_0
#
#
#
# ...
# libxslt-1.1.33       | 577 KB    | ##################################### | 100%
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import bs4 as bs
from bs4 import BeautifulSoup

# %%
# Lets define the url and get data using beautifulsoup
import requests
url=requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text

soup = BeautifulSoup(url, 'lxml')

# Table is in .table
table = soup.table

# Make dataframe and set data types
df = pd.read_html(str(table))[0]
df = df.astype(str)
df.shape
# Out:
# (180, 3)

# %%
# Drop all rows with N/A Borough
df = df[~df["Borough"].isin(["Not assigned"])]
df.shape
# Out:
# (103, 3)

# %%
# Ensure that Postal codes with multiple Neighbourhoods have them separated by
# commas (UPDATE: Wiki table is updated to separate with commas instead of slashes)
# OBSOLETE CODE:
df['Neighborhood'] = df['Neighborhood'].str.replace(' /',',')
df.shape
# Out:
# (103, 3)

# %%
# If a cell has a borough but a Not assigned neighborhood, 
# then the neighborhood will be the same as the borough

df.loc[df["Neighborhood"] == "NaN", "Neighborhood"] = df["Borough"]
df.shape
# Out:
# (103, 3)

# %%
# Reset index and print table
df = df.reset_index(drop=True)
df.head()
# Out:
#   Postal Code           Borough                                 Neighborhood
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
# Print final shape
df.shape
# Out:
# (103, 3)
